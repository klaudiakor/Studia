# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
# a) Load house sales data from file kc_house_data.csv, print first records.
# b) Print the variable list. Select categorical and numerical variables.
# c) Compute basic statistics of numerical variables. Are all of them meaningful?

# %%
#a)
#Your code:
data = pd.read_csv("kc_house_data.csv")
data.head()
#Hint: read_csv(), head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
len(data)
# Out:
# 21613

# %% [markdown]
#   The data are about sales of houses in the King Country area, between 2014 and 2015. The data set contains 21613 rows.

# %%
#b) 
print(data.keys())
house_categorical_df = ['id', 'date', 'waterfront', 'view', 'condition', 'grade', 'zipcode']
house_numerical_df = ['price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors','sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 
       'lat', 'long', 'sqft_living15', 'sqft_lot15']
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ### Categorical vs numerical variables
# * Numerical variables are this witch have arithmetical sense
# like price or number of bathrooms
# * Categorical variables  don't have mathematical sense eg. date of the home sale, waterfront (tells if the apartment was overlooking the waterfront), grade or zipcode

# %%
#c)
#Your code:
data[house_numerical_df].describe()
#Hint: Function describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       1.494309   1788.390691     291.509045   1971.005136     84.402258
# ...

# %% [markdown]
# In the count row, we can see that we have all data (no values are missing). \\
#
# The standard deviation of bedrooms is not meaningful because we can't have 0.9 of bedroom, it is always a natural number. Exactly the same situation we have with bathrooms and floors. More about these particular columns we can tell using min or max values. \\
#
# The Min row shows the minimum value in the set, thanks to this we can find that in our set we have houses without bedrooms or bathrooms which means that there are probably some office spaces or workshops or different types of spaces. \\
#
# Percentiles show the distribution of data. We can see for example that there were mainly 3 bedrooms houses. \\
#
# The Year of renovation isn't meaningful because in statistics we see mainly 0 because there is a small number of renovated houses. Similarly square footage of basement, there are only somewhere about 8500 houses with a square footage of the basement, not equal to 0. So if we compare it with all 20000 houses, it doesn't matter in statistics.

# %% [markdown]
# ## Exercise 2
# Using scatter plot:
# a) Show the relation of square footage and price.
# b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
# c) Check how good apartments are distributed over the city. First, plot zipcode versus price. Then, use apartments coordinates (longitude and lattitude) in order to show where apartments of good grade are located.

# %%
#a)
#Your code:
plt.scatter(data["sqft_living"], data["price"])
plt.xlabel("living sqft")
plt.ylabel("price")


#Hint plt.scatter
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# From the plot, we can conclude that price and living square footage are correlated. The larger the square footage is, the bigger price is.
# On this plot, we can also see the price range in which we can buy homes in specific square footage.

# %%
#b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
#Your code:
plt.scatter(data["grade"],data["price"])
plt.xlabel("grade")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# The higher the grade, the higher the price. The low grade tells us that probably this house needs to be renovated or is in a bad condition, so the price should be obviously lower.

# %%
#b cd.) Find other variables correlated with price.
plt.scatter(data["sqft_living15"],data["price"])
plt.xlabel("sqft_living15")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# sqft_living15 is the square footage of the 15 nearest neighbours. As we can see it is also correlated with price, this is probably because different estates can have different types of homes. I mean in different budgets.

# %%
plt.scatter(data["bathrooms"],data["price"])
plt.xlabel("bathrooms")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# The number of bathrooms is correlated with price. It can be because when there are more bathrooms, the house will have larger square footage.

# %%
#c)
#Your code:
plt.scatter(data["zipcode"],data["price"])
plt.xlabel("zipcode")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# There are some zip codes where the price range is bigger, this is probably richer neighborhoods.

# %%
#Your code:
plt.figure(figsize=(12,9))

plt.scatter(data["long"],data["lat"],s=10,c=data["grade"]) 
plt.xlabel("longitude")
plt.ylabel("latitude")

# import seaborn 
# seaborn.scatterplot(data = data, x=data["long"],y=data["lat"], hue=data["grade"]);
# Out:
# Text(0, 0.5, 'latitude')

# %% [markdown]
# The most sold houses are between 122.4 and 122.2 longitudes.
# In this plot, we can clearly see areas with different grades areas. Lighter areas have better grades.

# %% [markdown]
# ## Exercise 3
# a) Create boxplot of apartment's grade versus it's price. Compare with plot 2b).
# b) Create mosaic plot of any two categorical variables.

# %%
#a)
#Your code:
# import seaborn as sns
# sns.boxplot(x="grade", y="price", data=data)

data.boxplot(column =['price'], by='grade')
  

#Hint: plt.boxplot
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# This plot is analogous to plot 2b, but here we can see the density of our points and outliers.

# %%
#b)
from statsmodels.graphics.mosaicplot import mosaic

#Your code:

plt.rc("figure", figsize=(15,12))
mosaic(data, ['condition','grade'], title="condition & grade")
# Out:
# (<Figure size 1080x864 with 3 Axes>,
#  {('3', '7'): (0.0, 0.0, 0.6364633485837772, 0.35983711767306253),
#   ('3', '6'): (0.0,
#    0.36305255175666384,
#    0.6364633485837772,
#    0.07115617439656466),
#   ('3', '8'): (0.0,
#    0.43742416023682973,
#    0.6364633485837772,
#    0.29349343816322204),
#   ('3', '11'): (0.0,
#    0.734133032483653,
#    0.6364633485837772,
#    0.022824975748463268),
#   ('3', '9'): (0.0,
#    0.7601734423157176,
#    0.6364633485837772,
#    0.1403186009114865),
#   ('3', '5'): (0.0,
#    0.9037074773108055,
#    0.6364633485837772,
#    0.0068749926953202084),
#   ('3', '10'): (0.0,
#    0.9137979040897269,
#    0.6364633485837772,
#    0.0633186827238996),
#   ('3', '12'): (0.0,
#    0.9803320208972279,
#    0.6364633485837772,
#    0.005087494594537005),
#   ('3', '4'): (0.0,
#    0.9886349495753661,
#    0.6364633485837772,
#    0.0008937490503916549),
#   ('3', '3'): (0.0,
#    0.992744132709359,
#    0.6364633485837772,
# ...

# %% [markdown]
# The horizontal scale is condition with values from the range 1-5. \\
# The vertical scale is grade with values from the range 1-13. \\
#
# ---
#
# The most space takes houses which condition equal to 3, and grade 7.
# So these are average homes. They're not in bad or really good shape.
#
# Slightly less part of the mosaic takes houses also with condition 3 but grade 8, so these homes are similar to the first ones.
#
# When we look at condition equal to 4 most of the houses have grade 7. These homes are in pretty good shape but the grade is average on the scale.
#
# In the best condition (5) most homes also have grade 7.
#
# So a lot of homes get grade 7.
#
# A really small part of the plot takes homes with condition 1 or 2 and these ones with extreme values of grade.

# %% [markdown]
# ## Exercise 4
# "I am interested in the house with 3 bedrooms, 2 bathrooms and 2 floors"
# a) Compute the basic statistics of apartments fulfilling above constraints.
# b) Distinct accepted apartments on any of previously created plots.
# c) Find such apartments with best price to footage ratio.

# %%
#a)
#Your code:
selected_homes = data.loc[(data["bedrooms"]==3) & (data["bathrooms"] == 2) & (data["floors"] == 2)]
selected_homes.describe()
#Hint: pandas.DataFrame.loc
# Out:
#                  id         price  bedrooms  bathrooms  sqft_living  \
# count  1.540000e+02  1.540000e+02     154.0      154.0   154.000000
# mean   4.397177e+09  5.144986e+05       3.0        2.0  1850.279221
# std    2.849813e+09  2.497661e+05       0.0        0.0   547.585413
# min    7.600057e+06  2.090000e+05       3.0        2.0  1020.000000
# 25%    2.060901e+09  3.769750e+05       3.0        2.0  1452.500000
# 50%    3.630010e+09  4.640000e+05       3.0        2.0  1700.000000
# 75%    7.184074e+09  5.894625e+05       3.0        2.0  2127.500000
# max    9.829200e+09  1.755000e+06       3.0        2.0  3650.000000
#
#             sqft_lot  floors  waterfront        view   condition       grade  \
# count     154.000000   154.0  154.000000  154.000000  154.000000  154.000000
# mean    23678.948052     2.0    0.006494    0.357143    3.435065    7.551948
# std     83324.024708     0.0    0.080582    0.919495    0.713322    0.832684
# ...

# %% [markdown]
# There are data about houses with 3 bedrooms, 3 bathrooms and 2 floors. \\
# From this table, we can tell that this kind of home costs between 200'000 and 1'700'000. Square footage is between 1020 and 3650. So the difference is pretty big despite that these houses should be similar because we had a specified number of floors and rooms. So in these bigger houses, we have probably bigger rooms and maybe more space for eg. a living room or kitchen.

# %%
#b)
#Your code:
plt.figure(figsize=(12,9))
plt.scatter(data["grade"], data["price"], color = "black",s=15)
plt.scatter(selected_homes["grade"],selected_homes["price"], color = "yellow", edgecolors='k', s=70)
plt.xlabel("grade")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# The black plot is created from all data, the yellow one is from selected data (homes with 3 bedrooms, 2 bathrooms and 2 floors)
# We can see that the new data are concentrated in the centre, they have grades from 6 to 10, so these are pretty nice houses.

# %%
#Find such apartments with best price to footage ratio.
#find price for 1 sqft (pice/sqft)

def Calculate1SqftPrice(price, sqft):
  return price/sqft;


sqftPriceRatio = []
for i in range(0,len(selected_homes.index)):
  ratio = Calculate1SqftPrice(selected_homes["price"].values[i], selected_homes["sqft_living"].values[i])
  sqftPriceRatio.append(ratio)
  
selected_homes['sqft_price_ratio'] = sqftPriceRatio
sorted = selected_homes.sort_values(["sqft_price_ratio"], ascending = True)

sorted.head()
#Hint: .loc, .sort_values(), .index
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#                id             date     price  bedrooms  bathrooms  \
# 9704   7452500565  20140829T000000  260000.0         3        2.0
# 11258  7937600262  20140710T000000  379900.0         3        2.0
# 19880  3832050860  20150319T000000  210000.0         3        2.0
# 16014  5104450440  20141113T000000  252500.0         3        2.0
# 20906  3355400242  20141028T000000  274900.0         3        2.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 9704          2710      5000     2.0           0     0  ...        2710
# ...

# %% [markdown]
# There are apartments with best price to footage ratio.
# The best one cost 260'000 and have 2710 square footage.
